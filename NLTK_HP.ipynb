# %% [markdown]
# # Harry Potter and the Deathly Hallows
# ## 1. Import

# %%
import nltk
import re
from nltk import CFG
import string

# %%
'''
Step 2. Import corpus and segment into sentences
'''

text = ""
f = open('deathly_hallows.txt')
lines = f.readlines()


for line in lines[1:2]:
    text += line[4:].replace('\"', " ").replace('\\', '').strip()


all_sentences = [l.strip().replace("Harry Potter", "HarryPotter") for l in re.split('\.|\?', text) if l]
print(all_sentences)
# Out:
# ['The two men appeared out of nowhere, a few yards apart in the narrow, moonlit lane', "For a second they stood quite still, wands directed at each other's chests; then, recognizing each other, they stowed their wands beneath their cloaks and started walking briskly in the same direction", 'News', 'asked the taller of the two', 'The best,  replied Severus Snape', 'The lane was bordered on the left by wild, low-growing brambles, on the right by a high, neatly manicured hedge', "The men's long cloaks flapped around their ankles as they marched", 'Thought I might be late,  said Yaxley, his blunt features sliding in and out of sight as the branches of overhanging trees broke the moonlight', 'It was a little trickier than I expected', 'But I hope he will be satisfied', 'You sound confident that your reception will be good', 'Snape nodded, but did not elaborate', 'They turned right, into a wide driveway that led off the lane', "The high hedge curved into them, running off into the distance beyond the pair of imposing wrought-iron gates barring the men's way", 'Neither of them broke step: In silence both raised their left arms in a kind of salute and passed straight through, as though the dark metal was smoke', "The yew hedges muffled the sound of the men's footsteps", "There was a rustle somewhere to their right: Yaxley drew his wand again pointing it over his companion's head, but the source of the noise proved to be nothing more than a pure-white peacock, strutting majestically along the top of the hedge", 'He always did himself well, Lucius', 'Peacocks', 'Yaxley thrust his wand back under his cloak with a snort', 'A handsome manor house grew out of the darkness at the end of the straight drive, lights glinting in the diamond paned downstairs windows', 'Somewhere in the dark garden beyond the hedge a fountain was playing', 'Gravel crackled beneath their feet as Snape and Yaxley sped toward the front door, which swung inward at their approach, though nobody had visibly opened it', 'The hallway was large, dimly lit, and sumptuously decorated, with a magnificent carpet covering most of the stone floor', 'The eyes of the pale-faced portraits on the wall followed Snape and Yaxley as they strode past', 'The two men halted at a heavy wooden door leading into the next room, hesitated for the space of a heartbeat, then Snape turned the bronze handle', 'The drawing room was full of silent people, sitting at a long and ornate table', "The room's usual furniture had been pushed carelessly up against the walls", 'Illumination came from a roaring fire beneath a handsome marble mantelpiece surmounted by a gilded mirror', 'Snape and Yaxley lingered for a moment on the threshold', 'As their eyes grew accustomed to the lack of light, they were drawn upward to the strangest feature of the scene: an apparently unconscious human figure hanging upside down over the table, revolving slowly as if suspended by an invisible rope, and reflected in the mirror and in the bare, polished surface of the table below', 'None of the people seated underneath this singular sight were looking at it except for a pale young man sitting almost directly below it', 'He seemed unable to prevent himself from glancing upward every minute or so', 'Yaxley', 'Snape,  said a high, clear voice from the head of the table', 'You are very nearly late', 'The speaker was seated directly in front of the fireplace, so that it was difficult, at first, for the new arrivals to make out more than his silhouette', 'As they drew nearer, however, his face shone through the gloom, hairless, snakelike, with slits for nostrils and gleaming red eyes whose pupils were vertical', 'He was so pale that he seemed to emit a pearly glow', 'Severus, here,  said Voldemort, indicating the seat on his immediate right', 'Yaxley – beside Dolohov', 'The two men took their allotted places', 'Most of the eyes around the table followed Snape, and it was to him that Voldemort spoke first', 'So', 'My Lord, the Order  ...

# %% [markdown]
# ## 2. Statistics

# %%
# https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

'''
Step 2. Tokenize text
'''
tokens = nltk.word_tokenize(text)
tokens = [token.lower() for token in tokens]

list_of_tokens = nltk.pos_tag(tokens)
# print(list_of_tokens)

print("Aantal woorden:" , len(tokens))

'''
Tokenize sentences
'''
sentences = nltk.sent_tokenize(text)
print("Aantal zinnen: ", len(sentences))
print(sentences)

# normalized_text = "".join([w.lower() for w in text])
# normalized_tokens = nltk.word_tokenize(normalized_text)

porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()


# normalized_tokens = [porter.stem(t) for t in tokens]
# normalized_tokens = [lancaster.stem(t) for t in tokens]

unique_normalized_tokens = set(tokens)

wnl = nltk.WordNetLemmatizer()
vocabulary = [wnl.lemmatize(t) for t in unique_normalized_tokens]
print("Aantal vocabulary: ", len(vocabulary))


# vocab_2 = sorted(set(words))


hapaxes = []
most_frequent = ""
fdist = nltk.FreqDist(tokens)

del fdist[',']
del fdist['.']


sorted_frequencies = sorted(fdist, key=fdist.get, reverse=True)
for word in sorted_frequencies:
    if word not in string.punctuation:
        if fdist[word] == 1:
            hapaxes.append((word, fdist[word]))
#         print(word, fdist[word], end='\n')

print("Most frequent word: ", fdist.most_common(1)[0])
# for hapax in hapaxes:
#     print(hapax)
    
    
# print(fdist.most_common(10))
# Out:
# Aantal woorden: 3661
# Aantal zinnen:  215
# ['The two men appeared out of nowhere, a few yards apart in the narrow, moonlit lane.', "For a second they stood quite still, wands directed at each other's chests; then, recognizing each other, they stowed their wands beneath their cloaks and started walking briskly in the same direction.", 'News?', 'asked the taller of the two.', 'The best,  replied Severus Snape.The lane was bordered on the left by wild, low-growing brambles, on the right by a high, neatly manicured hedge.', "The men's long cloaks flapped around their ankles as they marched.", 'Thought I might be late,  said Yaxley, his blunt features sliding in and out of sight as the branches of overhanging trees broke the moonlight.', 'It was a little trickier than I expected.', 'But I hope he will be satisfied.', 'You sound confident that your reception will be good?', 'Snape nodded, but did not elaborate.', 'They turned right, into a wide driveway that led off the lane.', "The high hedge curved into them, running off into the distance beyond the pair of imposing wrought-iron gates barring the men's way.", "Neither of them broke step: In silence both raised their left arms in a kind of salute and passed straight through, as though the dark metal was smoke.The yew hedges muffled the sound of the men's footsteps.", "There was a rustle somewhere to their right: Yaxley drew his wand again pointing it over his companion's head, but the source of the noise proved to be nothing more than a pure-white peacock, strutting majestically along the top of the hedge.", 'He always did himself well, Lucius.', 'Peacocks ...  Yaxley thrust his wand back under his cloak with a snort.A handsome manor house grew out of the darkness at the end of the straight drive, lights glinting in the diamond paned downstairs windows.', 'Somewhere in the dark garden beyond the hedge a fountain was playing.', 'Gravel crackled beneath their feet as Snape and Yaxley sped toward the front door, which swung inward at their approach, though nobody had visibly opened it.The hallway was large, dimly lit, and sumptuously decorated, with a magnificent carpet covering most of the stone floor.', 'The eyes of the pale-faced portraits on the wall followed Snape and Yaxley as they strode past.', 'The two men halted at a heavy wooden door leading into the next room, hesitated for the space of a heartbeat, then Snape turned the bronze handle.The drawing room was full of silent people, sitting at a long and ornate table.', "The room's usual furniture had been pushed carelessly up against the walls.", 'Illumination came from a roaring fire beneath a handsome marble mantelpiece surmounted by a gilded mirror.', 'Snape and Yaxley lingered for a moment on the threshold.', 'As their eyes grew accustomed to the lack of light, they were drawn upward to the strangest feature of the scene: an apparently unconscious human figure hanging upside down over the table, revolving slowly as if suspended by an invisible rope, and reflected in the mirror and in the bare, polished surface of the table below.', 'None of the people seated underneath this singular sight were looking at it except for a pale young man sitting almost directly below it.', 'He seemed unable to prevent himself from glancing upward every minute or so.', 'Yaxley.', 'Snape,  said a high, clear voice from the head of the table.', 'You are very nearly late.', 'The speaker was seated directly in front of the fireplace, so that it was difficult, at first, for the new arrivals to make out more than his silhouette.', 'As they drew nearer, however, his face shone through the gloom, hairless, snakelike, with slits for nostrils and gleaming red eyes whose pupils were vertical.', 'He was so pale that he seemed to emit a pearly glow.', 'Severus, here,  said Voldemort, indicating the seat on his immediate right.', 'Yaxley – beside Dolohov.', 'The two men took their allotted places.', 'Most of the eyes around the table followed Snape, and it was to him that Voldemort spoke first.', 'S ...
# Aantal vocabulary:  1032
# Most frequent word:  ('the', 195)

# %% [markdown]
# ## 3. Tokenizing

# %%
from collections import defaultdict

tag_dict = defaultdict(list)

# Tag
tokens = nltk.word_tokenize(text)
tokens = [token.lower() for token in tokens]
tagged_sent = nltk.pos_tag(tokens)

for word, tag in tagged_sent:
    if tag not in tag_dict:
        tag_dict[tag].append(word)
    elif word not in tag_dict.get(tag):
        tag_dict[tag].append(word)

lexicon = ""
# Printing to screen
for tag, words in tag_dict.items():
    if ',' in tag or ':' in tag or '.' in tag or '$' in tag:
        continue
    lexicon += tag + " -> "
#     print(tag, "->", end='')
    first_word = True
    for word in words:
        if first_word:
            lexicon += "\"" + word + "\""
#             print("\"" + word + "\"", end='')
            first_word = False
        else:
            lexicon += "| \"" + word + "\""
#             print("| \"" + word + "\"", end='')
#     print('\n')
    lexicon += "\n"

print(lexicon)
# Out:
# RBR -> "more"| "louder"
# NN -> "narrow"| "lane"| "direction"| "news"| "taller"| "severus"| "snape.the"| "right"| "hedge"| "cloaks"| "i"| "yaxley"| "blunt"| "sight"| "moonlight"| "hope"| "reception"| "snape"| "driveway"| "distance"| "pair"| "way"| "step"| "silence"| "kind"| "salute"| "dark"| "metal"| "yew"| "sound"| "rustle"| "wand"| "companion"| "head"| "source"| "noise"| "nothing"| "peacock"| "top"| "lucius"| "cloak"| "manor"| "house"| "darkness"| "end"| "drive"| "diamond"| "garden"| "fountain"| "gravel"| "front"| "door"| "inward"| "approach"| "nobody"| "hallway"| "lit"| "carpet"| "stone"| "floor"| "wall"| "wooden"| "room"| "space"| "heartbeat"| "bronze"| "handle.the"| "table"| "furniture"| "illumination"| "fire"| "beneath"| "mantelpiece"| "mirror"| "moment"| "threshold"| "lack"| "light"| "feature"| "scene"| "figure"| "rope"| "bare"| "surface"| "none"| "man"| "minute"| "voice"| "speaker"| "fireplace"| "silhouette"| "nearer"| "face"| "shone"| "gloom"| "hairless"| "snakelike"| "glow"| "voldemort"| "seat"| "beside"| "dolohov"| "lord"| "order"| "phoenix"| "harry"| "potter"| "place"| "safety"| "interest"| "gazing"| "saturday"| "nightfall"| "intensity"| "ferocity"| "gaze"| "lipless"| "mouth"| "something"| "smile"| "information"| "–"| "auror"| "slip"| "thirtieth"| "night"| "boy"| "trail"| "doubt"| "confundus"| "charm"| "time"| "assure"| "dawlish"| "office"| "part"| "protection"| "ministry"| "thing"| "wheezy"| "giggle"| "table.voldemort"| "laugh"| "body"| "thought"| "party"| "hand"| "home"| "chance"| "course"| "opportunity"| "rest"| "firelight"| "score"| "difficulty"| "effort"| "curse"| "thicknesse"| "neighbor"| "back"| "start"| "act"| "attempt"| "minister"| "life"| "department"| "law"| "enforcement"| "contact"| "official"| "control"| "friend"| "rate"| "destination"| "advantage"| "portion"| "approval"| "transport"| "floo"| "network"| "form"| "everything"| "person"| "triumphs"| "company"| "expression"| "existence"| "luck"| "response"| "wail"| "cry"| "misery"| "pain"| "wormtail"| "change"| "tone"| "prisoner"| "chair"| "glance"| "gleam"| "silver"| "instance"| "shock"| "let"| "reason"| "malfoy"| "skin"| "waxy"| "hoarse"| "wife"| "hair"| "slim"| "briefly"| "wrist"| "touch"| "elm"| "core"| "dragon"| "heartstring"| "movement"| "fraction"| "exchange"| "gesture"| "throng"| "liberty"| "family"| "presence"| "cruel"| "shudder"| "hissing"| "table.the"| "snake"| "neck"| "thickness"| "creature"| "lot"| "return"| "rise"| "power"| "shook"| "sweat"| "lip"| "left"| "nod"| "son"| "draco"| "inert"| "eye"| "woman"| "emotion"| "honor"| "pleasure"| "sister"| "bearing"| "demeanor"| "bellatrix"| "longing"| "closeness"| "side"| "deal"| "color"| "delight"| "truth"| "event"| "hear"| "week"| "niece"| "narcissa"| "werewolf"| "remus"| "lupin"| "eruption"| "laughter"| "disturbance"| "death"| "humiliation"| "happiness"| "blotchy"| "outpouring"| "mirth"| "mudblood"| "brat"| "beast"| "cubs"| "hilarity"| "terror"| "father"| "lap"| "mother"| "deadpan"| "stare"| "breathless"| "imploring"| "health"| "swam"| "gratitude"| "world"| "cancer"| "blood"| "remain"| "flick"| "groan"| "voldemort.snape"| "captive"| "permission"| "curiosity"| "ah"| "snout"| "anymore"| "charity"| "burbage"| "taught"| "school"| "witchcraft"| "wizardry"| "comprehension"| "professor"| "please"| "twitch"| "defense"| "prophet"| "knowledge"| "magic"| "dwindling"| "circumstance"| "anger"| "contempt"| "flash"| "corner"| "resounding"| "crash"| "dinner"| "nagini"| "wood"
# PDT -> "beneath"| "all"
# WP -> "who"| "what"
# PRP -> "they"| "it"| "he"| "you"| "them"| "himself"| "yaxley"| "him"| "themselves"| "we"| "me"| "us"| "she"| "her"| "yours"
# RP -> "off"| "back"| "out"| "down"| "up"| "around"| "scrimgeour"| "away"
# JJ -> "few"| "moonlit"| "second"| "other"| "same"| "wild"| "low-growing"| "high"| "long"| "late"| "little"| "i"| "confident"| "good"| "right"| "wide"| "wrought-iron"| "left"| "smoke.the"| "pure-white"| "snort.a"| "handsome"| "straight"| "downstairs"| "dark"| "it.the"| "large"| "magnificent"| "pale-faced"| "past"| "heavy"| "next"| "full"| "silent"| "ornate"| "usual"| "marble"| "gilded"| "unconscious"| "human"| "invisible"| "singular"| "pale"| "young"| "unable"| "upward"| "clear"| "difficult"| "first"| "new"| "red"| "vertical"| "immediate"| "–"| "allotted"| "current"| "saturday"| "black"| "such"| "fearful"| "dawlish"| "seventeen"| "false"| "susceptible"| "certain"| "further"| "squat"| "short"| "overhead"| "entire"| "white"| "undo"| "great"| "imperius"| "pius"| "many"| "impressed"| "twisted"| "true"| "magical"| "easy"| "high-ranking"| "unlikely"| "mine"| "several"| "potter"| "open"| "revolving"| "own"| "continued"| "careless"| "best-laid"| "harry"| "sudden"| "terrible"| "drawn-out"| "quiet"| "thoughtful"| "m-my"| "small"| "low"| "unoccupied"| "curious"| "tense"| "displayed"| "lucius"| "yellowish"| "blonde"| "involuntary"| "happy"| "soft"| "huge"| "thigh"| "thin"| "unhappy"| "upper"| "odd"| "stiff"| "rigid"| "impassive"| "mere"| "proud"| "gleeful"| "giant"| "jubilant"| "narcissa"| "opposite"| "angry"| "enough"| "healthy"| "tiny"| "upside"| "cracked"| "terrified"| "wand-free"| "hogwarts"| "broad"| "pointed"| "different"| "content"| "last"| "impassioned"| "daily"| "desirable"| "third"| "green"| "polished"
# VB -> "be"| "elaborate"| "prevent"| "make"| "emit"| "move"| "look"| "speak"| "let"| "lay"| "play"| "transfer"| "hide"| "provide"| "i"| "give"| "discover"| "break"| "scrimgeour"| "set"| "subjugate"| "work"| "bring"| "touch"| "receive"| "know"| "do"| "have"| "take"| "attend"| "understand"| "kill"| "issue"| "need"| "borrow"| "see"| "voldemort"| "lucius"| "hiss"| "climb"| "rest"| "desire"| "malfoy"| "demonstrate"| "exchange"| "hear"| "draco"| "babysit"| "prune"| "keep"| "cut"| "struggle"| "recognize"| "show"| "face"| "help"| "accept"| "avada"
# TO -> "to"
# UH -> "yes"
# RB -> "nowhere"| "apart"| "quite"| "still"| "then"| "briskly"| "neatly"| "not"| "straight"| "through"| "somewhere"| "again"| "majestically"| "always"| "well"| "visibly"| "dimly"| "sumptuously"| "carelessly"| "upward"| "apparently"| "upside"| "down"| "slowly"| "almost"| "directly"| "so"| "very"| "nearly"| "late"| "however"| "pearly"| "here"| "first"| "palpably"| "away"| "calmly"| "back"| "forward"| "differently"| "naturally"| "yaxley"| "there"| "once"| "resentfully"| "together"| "enough"| "strangely"| "only"| "–"| "also"| "now"| "as"| "long"| "immediately"| "either"| "far"| "up"| "too"| "due"| "apprehensively"| "better"| "seemingly"| "downward"| "halfway"| "anymore"| "ahead"| "closely"| "maliciously"| "even"| "barely"| "endlessly"| "absently"| "quickly"| "heavily"| "lips"| "evidently"| "n't"| "just"| "angrily"| "recently"| "ugly"| "never"| "clearly"| "imperceptibly"| "jerkily"| "softly"
# NNS -> "men"| "yards"| "wands"| "chests"| "cloaks"| "brambles"| "ankles"| "features"| "branches"| "trees"| "gates"| "arms"| "hedges"| "footsteps"| "peacocks"| "lights"| "windows"| "feet"| "eyes"| "portraits"| "people"| "walls"| "arrivals"| "slits"| "nostrils"| "pupils"| "places"| "others"| "ones"| "watchers"| "plans"| "aurors"| "enchantments"| "heads"| "shoulders"| "departments"| "apparates"| "mistakes"| "lives"| "errors"| "wreckers"| "things"| "words"| "followers"| "i"| "volunteers"| "sideways"| "fingers"| "robes"| "lengths"| "lies"| "wizards"| "heavy"| "malfoys"| "years"| "looks"| "tears"| "fists"| "eaters"| "ours"| "–"| "catcalls"| "jeers"| "yours"| "parts"| "bonds"| "classes"| "noises"| "teeth"| "yes"| "children"| "witches"| "muggles"| "minds"| "mudbloods"| "thieves"| "purebloods"| "werewolves"| "chairs"
# VBD -> "appeared"| "stood"| "directed"| "stowed"| "started"| "asked"| "replied"| "was"| "marched"| "said"| "broke"| "nodded"| "did"| "turned"| "led"| "curved"| "raised"| "passed"| "muffled"| "drew"| "proved"| "thrust"| "grew"| "paned"| "crackled"| "sped"| "had"| "followed"| "came"| "lingered"| "were"| "reflected"| "polished"| "seated"| "seemed"| "took"| "spoke"| "sharpened"| "stiffened"| "fidgeted"| "looked"| "discussed"| "waited"| "went"| "told"| "got"| "gave"| "held"| "subsided"| "called"| "squared"| "succeeded"| "clapped"| "failed"| "watched"| "startled"| "gasped"| "scrambled"| "continued"| "wanted"| "glanced"| "closed"| "put"| "withdrew"| "whispered"| "made"| "expected"| "widened"| "sniggered"| "repressed"| "emerged"| "rose"| "stroked"| "professed"| "wiped"| "terrified"| "halfway"| "sat"| "lidded"| "leaned"| "tilted"| "considered"| "stared"| "parted"| "thumped"| "opened"| "hissed"| "cried"| "married"| "carried"| "mounted"| "caught"| "shook"| "resumed"| "died"| "pointed"| "began"| "revolved"| "hunched"| "cackled"| "taught"| "fell"| "wrote"| "laughed"| "kedavra"| "trembled"| "creaked"
# IN -> "out"| "of"| "in"| "for"| "at"| "on"| "by"| "around"| "as"| "than"| "that"| "into"| "beyond"| "though"| "over"| "along"| "under"| "with"| "toward"| "up"| "against"| "from"| "if"| "below"| "underneath"| "except"| "so"| "through"| "upon"| "after"| "like"| "until"| "before"| "next"| "unless"| "while"| "within"| "above"| "without"| "about"| "down"| "behind"| "beneath"| "across"| "–"| "beside"| "unlike"| "since"| "onto"
# JJR -> "trickier"| "more"| "better"| "easier"| "less"| "higher"
# VBP -> "beneath"| "sound"| "strode"| "are"| "have"| "think"| "know"| "mistrust"| "afraid"| "i"| "understand"| "go"| "see"| "require"| "seem"| "lucius"| "do"| "look"| "speak"| "mean"| "'m"| "–"| "say"| "become"| "threaten"| "spat"| "mate"| "leapt"
# POS -> "'s"| "'"
# VBN -> "bordered"| "left"| "manicured"| "flapped"| "thought"| "expected"| "satisfied"| "opened"| "decorated"| "halted"| "hesitated"| "been"| "pushed"| "surmounted"| "accustomed"| "drawn"| "suspended"| "seated"| "repeated"| "fastened"| "scorched"| "leaned"| "turned"| "heard"| "moved"| "placed"| "known"| "confunded"| "infiltrated"| "echoed"| "wandered"| "lost"| "used"| "given"| "fallen"| "–"| "surrounded"| "regular"| "discovered"| "converted"| "done"| "determined"| "planted"| "controlled"| "regulated"| "concerned"| "blamed"| "thwarted"| "sounded"| "seemed"| "i"| "spoken"| "scurried"| "announced"| "sunken"| "shadowed"| "compared"| "missed"| "noticed"| "stopped"| "averted"| "constricted"| "flooded"| "welled"| "taken"| "confused"| "married"| "flushed"| "set"| "asked"| "looked"| "diseased"| "gazed"| "woken"| "joined"| "tonight"| "gagged"| "illuminated"| "swayed"| "slithered"
# CC -> "and"| "but"| "or"| "yaxley"| "nor"
# WRB -> "where"| "when"| "why"| "how"
# VBG -> "recognizing"| "walking"| "sliding"| "overhanging"| "running"| "imposing"| "barring"| "pointing"| "strutting"| "glinting"| "playing"| "covering"| "leading"| "drawing"| "sitting"| "roaring"| "hanging"| "revolving"| "looking"| "glancing"| "gleaming"| "indicating"| "smiling"| "watching"| "going"| "according"| "taking"| "placing"| "eschewing"| "speaking"| "addressing"| "removing"| "keeping"| "leaving"| "saying"| "staring"| "examining"| "moving"| "unblinking"| "gazing"| "talking"| "jeering"| "disliking"| "stroking"| "corrupting"| "polluting"| "wizarding"| "mistaking"| "pouring"
# CD -> "two"| "one"
# DT -> "the"| "a"| "each"| "neither"| "both"| "an"| "this"| "every"| "nightfall"| "some"| "all"| "no"| "that"| "those"| "any"| "these"| "either"| "another"
# VBZ -> "swung"| "intends"| "comes"| "faces"| "turns"| "has"| "is"| "believes"| "remains"| "travels"| "uses"| "displaces"| "means"| "knows"| "marries"| "trees"| "infects"| "says"
# JJS -> "best"| "most"| "strangest"| "oldest"| "guest"
# WDT -> "that"| "which"
# FW -> "eh"| "yaxley"| "narcissa"| "sat"
# RBS -> "most"
# NNP -> "–"
# EX -> "there"
# MD -> "might"| "will"| "would"| "must"| "could"| "can"| "shall"

# %% [markdown]
# ## 4. Grammar

# %%
# print(all_sentences[0:10])
# print()
from nltk.grammar import FeatureGrammar
from nltk.parse import RecursiveDescentParser, FeatureEarleyChartParser
from nltk.parse.generate import generate


tagged_sent = nltk.pos_tag(tokens)
# print(tagged_sent)

extend_grammar = """
    S -> NP
    NP -> DT JJ NN VBD
"""

cfg_1 = CFG.fromstring(extend_grammar + lexicon)
cfg_1_parser = RecursiveDescentParser(cfg_1)

feature_grammar = """
    S -> NP VP
    NP -> DT NN
    VP -> VB NP
"""

cfg_2 = FeatureGrammar.fromstring(feature_grammar + lexicon)
cfg_2_parser = FeatureEarleyChartParser(cfg_2)

# %%
# print(cfg_2)

# groucho_grammar = nltk.CFG.fromstring("""
#     S -> NP VP
#     PP -> P NP
#     NP -> Det N | Det N PP | 'I'
#     VP -> V NP | VP PP
#     Det -> 'an' | 'my'
#     N -> 'elephant' | 'pajamas'
#     V -> 'shot'
#     P -> 'in'
# """)

# sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(cfg_2)
for tree in parser.parse(['the', 'two', 'men', 'appeared', 'out', 'of', 'nowhere', 'a', 'few', 'yards', 'apart', 'in', 'the', 'narrow', 'moonlit', 'lane']):
    print(tree)

# %%
feature_grammar = """
    S -> NP VP
    NP -> DT NN
    VP -> VB NP
"""

cfg_2 = FeatureGrammar.fromstring(feature_grammar + lexicon)

# The following inputs should produce the corresponding results
for s in generate(cfg_2, n=10): 
    print(' '.join(s))
# Out:
# the narrow be the narrow
# the narrow be the lane
# the narrow be the direction
# the narrow be the news
# the narrow be the taller
# the narrow be the severus
# the narrow be the snape.the
# the narrow be the right
# the narrow be the hedge
# the narrow be the cloaks

# %%
tokenized_sentences = []
for sentence in sentences:
    tokenzed_sen = []
    for word in sentence.split(" "):
        for tag in tagged_sent:
            if tag[0] in word.lower().replace(",", ""):
                tokenzed_sen.append(tag[1])
                break
    tokenized_sentences.append(tokenzed_sen)


for idx, sentence in enumerate(tokenized_sentences):
    print(sentence, "\n", all_sentences[idx])
# Out:
# ['DT', 'CD', 'NNS', 'VBD', 'IN', 'IN', 'RB', 'DT', 'JJ', 'DT', 'DT', 'IN', 'DT', 'DT', 'JJ', 'DT']
#  The two men appeared out of nowhere, a few yards apart in the narrow, moonlit lane
# ['IN', 'DT', 'JJ', 'DT', 'VBD', 'RB', 'RB', 'DT', 'VBD', 'DT', 'DT', 'DT', 'NNS', 'DT', 'IN', 'DT', 'DT', 'DT', 'VBD', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'RB', 'IN', 'DT', 'DT', '.']
#  For a second they stood quite still, wands directed at each other's chests; then, recognizing each other, they stowed their wands beneath their cloaks and started walking briskly in the same direction
# ['NN']
#  News
# ['DT', 'DT', 'DT', 'IN', 'DT', 'CD']
#  asked the taller of the two
# ['DT', 'JJS', 'VBD', 'NN', 'DT', 'DT', 'DT', 'VBN', 'IN', 'DT', 'VBN', 'IN', 'JJ', 'IN', 'DT', 'IN', 'DT', 'NN', 'IN', 'DT', 'JJ', 'DT', 'DT', '.']
#  The best,  replied Severus Snape
# ['DT', 'NNS', 'IN', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT']
#  The lane was bordered on the left by wild, low-growing brambles, on the right by a high, neatly manicured hedge
# ['VBN', 'NN', 'NN', 'VB', 'DT', 'DT', 'DT', 'NN', 'NN', 'DT', 'IN', 'IN', 'DT', 'IN', 'IN', 'NN', 'DT', 'DT', 'DT', 'IN', 'DT', 'NNS', 'VBD', 'DT', '.']
#  The men's long cloaks flapped around their ankles as they marched
# ['NN', 'DT', 'DT', 'NN', 'NN', 'DT', 'NN', '.']
#  Thought I might be late,  said Yaxley, his blunt features sliding in and out of sight as the branches of overhanging trees broke the moonlight
# ['CC', 'NN', 'NN', 'PRP', 'NN', 'VB', 'DT']
#  It was a little trickier than I expected
# ['PRP', 'VBP', 'IN', 'DT', 'PRP', 'IN', 'NN', 'VB', '.']
#  But I hope he will be satisfied
# ['DT', 'VBD', 'CC', 'NN', 'RB', 'DT']
#  You sound confident that your reception will be good
# ['DT', 'VBD', 'NN', 'IN', 'DT', 'NN', 'DT', 'DT', 'VBD', 'IN', 'DT', 'DT']
#  Snape nodded, but did not elaborate
# ['DT', 'JJ', 'NN', 'VBD', 'IN', 'DT', 'IN', 'IN', 'IN', 'DT', 'DT', 'IN', 'DT', 'DT', 'IN', 'IN', 'IN', 'DT', 'DT', 'DT', 'NNS', 'DT']
#  They turned right, into a wide driveway that led off the lane
# ['DT', 'IN', 'DT', 'VBD', 'NN', 'IN', 'NN', 'DT', 'DT', 'DT', 'VBN', 'DT', 'IN', 'DT', 'IN', 'IN', 'DT', 'DT', 'DT', 'DT', 'RB', 'DT', 'IN', 'DT', 'DT', 'DT', 'DT', 'DT', 'NN', 'NN', 'VBD', 'DT', 'VBP', 'IN', 'DT', 'NNS', '.']
#  The high hedge curved into them, running off into the distance beyond the pair of imposing wrought-iron gates barring the men's way
# ['DT', 'DT', 'DT', 'NN', 'PRP', 'TO', 'DT', 'NN', 'DT', 'VBD', 'NN', 'DT', 'DT', 'IN', 'NN', 'IN', 'NN', 'DT', 'DT', 'CC', 'DT', 'NN', 'IN', 'DT', 'NN', 'VBD', 'TO', 'VB', 'IN', 'JJR', 'DT', 'DT', 'NN', 'DT', 'IN', 'DT', 'DT', 'DT', 'TO', 'IN', 'DT', '.']
#  Neither of them broke step: In silence both raised their left arms in a kind of salute and passed straight through, as though the dark metal was smoke
# ['PRP', 'DT', 'NN', 'NN', 'RB', '.']
#  The yew hedges muffled the sound of the men's footsteps
# ['DT', '.', 'DT', 'VBD', 'NN', 'DT', 'DT', 'IN', 'NN', 'DT', 'NN', 'DT', 'DT', 'DT', 'DT', 'NN', 'VBD', 'IN', 'IN', 'DT', 'DT', 'DT', 'DT', 'NN', 'IN', 'DT', 'DT', 'NN', 'NN', 'IN', 'IN', 'DT', 'DT', 'DT', 'DT', 'IN']
#  There was a rustle somewhere to their right: Yaxley drew his wand again pointing it over his companion's head, but the source of the noise proved to be nothing more than a pure-white peacock, strutting majestically along the top of the hedge
# ['PRP', 'IN', 'DT', 'DT', 'DT', 'IN', 'DT', 'NN', 'DT', 'DT', 'DT', 'DT']
#  He always did himself well, Lucius
# ['DT', 'DT', 'DT', 'DT', 'NNS', 'DT', 'DT', 'DT', 'DT', 'VBD', 'DT', 'DT', 'IN', 'NN', 'NN', 'VBZ', 'DT', 'DT', 'DT', 'DT', 'IN', 'NN', 'DT', 'NN', 'VBN', 'DT', 'DT', 'DT', 'DT', 'NN', 'NN', 'DT', 'RB', 'DT', 'NN', 'DT', 'DT', 'DT', 'IN', 'JJS', 'IN', 'DT', 'IN', '.']
#  Peacocks
# ['DT', 'NNS', 'IN', 'DT', 'DT', 'DT', 'IN', 'DT', 'DT', 'VBD', 'DT', 'DT', 'DT', 'DT', 'DT', 'VBP', 'DT']
#  Yaxley thrust his wand back under his cloak with a snort
# ['DT', 'CD', 'NNS', 'DT', 'DT', 'DT', 'DT', 'NN', 'NN', 'DT', 'IN', 'DT', 'JJ', 'NN', 'DT', 'IN', 'DT', 'DT', 'IN', 'DT', 'DT', 'DT', 'DT', 'VBD', 'DT', 'IN', 'DT', 'DT', 'NN', 'DT', 'JJ', 'IN', 'NN', 'NNS', 'IN', 'DT', 'DT', 'IN', 'DT', 'DT', 'DT']
#  A handsome manor house grew out of the darkness at the end of the straight drive, lights glinting in the diamond paned downstairs windows
# ['DT', 'POS', 'DT', 'NN', 'DT', 'VB', 'PRP', 'DT', 'IN', 'DT', 'DT', 'DT']
#  Somewhere in the dark garden beyond the hedge a fountain was playing
# ['DT', 'DT', 'IN', 'DT', 'DT', 'NN', 'DT', 'DT', 'DT', 'DT', 'DT', 'VBN', 'IN', 'DT', 'NN', '.']
#  Gravel crackled beneath their feet as Snape and Yaxley sped toward the front door, which swung inward at their approach, though nobody had visibly opened it
# ['DT', 'DT', 'DT', 'IN', 'IN', 'DT', 'NNS', 'IN', 'DT', '.']
#  The hallway was large, dimly lit, and sumptuously decorated, with a magnificent carpet covering most of the stone floor
# ['DT', 'DT', 'NNS', 'VBD', 'DT', 'TO', 'DT', 'DT', 'IN', 'NN', 'DT', 'VBD', 'DT', 'DT', 'TO', 'DT', 'DT', 'DT', 'IN', 'DT', ':', 'DT', 'DT', 'IN', 'DT', 'NN', 'DT', 'NN', 'RB', 'IN', 'DT', 'DT', 'IN', 'RB', 'DT', 'NN', 'NN', 'IN', 'DT', 'IN', 'NN', 'DT', 'VBD', 'IN', 'DT', 'NN', 'DT', 'IN', 'DT', 'DT', 'NN', 'DT', 'IN', 'DT', 'DT', '.']
#  The eyes of the pale-faced portraits on the wall followed Snape and Yaxley as they strode past
# ['IN', 'IN', 'DT', 'NNS', 'DT', 'DT', 'NN', 'DT', 'NN', 'VBD', 'IN', 'DT', 'NN', 'IN', 'IN', 'DT', 'DT', 'PRP', 'DT', 'IN', 'DT', 'NN', 'VB', '.']
#  The two men halted at a heavy wooden door leading into the next room, hesitated for the space of a heartbeat, then Snape turned the bronze handle
# ['PRP', 'VBD', 'DT', 'TO', 'VB', 'NN', 'IN', 'DT', 'DT', 'DT', 'IN', 'CC', '.']
#  The drawing room was full of silent people, sitting at a long and ornate table
# ['DT']
#  The room's usual furniture had been pushed carelessly up against the walls
# ['DT', 'DT', 'DT', 'JJ', 'DT', 'NN', 'IN', 'DT', 'DT', 'IN', 'DT', 'DT']
#  Illumination came from a roaring fire beneath a handsome marble mantelpiece surmounted by a gilded mirror
# ['PRP', 'DT', 'RB', 'DT', 'DT']
#  Snape and Yaxley lingered for a moment on the threshold
# ['DT', 'DT', 'DT', 'DT', 'NN', 'IN', 'IN', 'IN', 'DT', 'DT', 'RB', 'DT', 'NN', 'DT', 'NN', 'DT', 'NN', 'IN', 'DT', 'JJ', 'DT', 'TO', 'DT', 'IN', 'JJR', 'DT', 'NN', '.']
#  As their eyes grew accustomed to the lack of light, they were drawn upward to the strangest feature of the scene: an apparently unconscious human figure hanging upside down over the table, revolving slowly as if suspended by an invisible rope, and reflected in the mirror and in the bare, polished surface of the table below
# ['DT', 'DT', 'VBD', 'DT', 'RB', 'NN', 'DT', 'IN', 'RB', 'DT', 'NN', 'DT', 'DT', 'NN', 'NN', 'IN', 'NN', 'DT', 'DT', 'JJ', 'NNS', 'WP$', 'NN', 'VBD', 'DT']
#  None of the people seated underneath this singular sight were looking at it except for a pale young man sitting almost directly below it
# ['PRP', 'DT', 'RB', 'DT', 'DT', 'PRP', 'VBD', 'TO', 'NN', 'DT', 'DT', '.']
#  He seemed unable to prevent himself from glancing upward every minute or so
# ['NN', 'PRP', 'DT', 'CC', 'DT', 'DT', 'DT', 'IN', 'NN', 'DT', '.']
#  Yaxley
# ['DT', 'JJ', 'NN', '.']
#  Snape,  said a high, clear voice from the head of the table
# ['DT', 'CD', 'NNS', 'TO', 'DT', 'DT', 'DT']
#  You are very nearly late
# ['JJS', 'IN', 'DT', 'NNS', 'DT', 'DT', 'DT', 'VBD', 'DT', 'DT', 'NN', 'DT', 'TO', 'NN', 'DT', 'CC', 'VBD', '.']
#  The speaker was seated directly in front of the fireplace, so that it was difficult, at first, for the new arrivals to make out more than his silhouette
# ['.']
#  As they drew nearer, however, his face shone through the gloom, hairless, snakelike, with slits for nostrils and gleaming red eyes whose pupils were vertical
# ['PRP$', 'CC', 'DT', 'CC', 'IN', 'DT', 'NN', 'IN', 'TO', 'VB', 'DT', 'NN', 'IN', 'NN', 'JJ', 'DT', 'IN', 'DT', 'IN', 'DT', 'JJ', 'DT', 'DT']
#  He was so pale that he seemed to emit a pearly glow
# ['DT', 'IN', 'DT', 'DT', 'DT', 'DT', 'DT', 'RB', 'NN', 'DT', 'NN', 'DT', 'DT', 'DT', 'DT', 'DT', '.']
#  Severus, here,  said Voldemort, indicating the seat on his immediate right
# ['DT', '.', 'DT', 'DT', 'DT', '.']
#  Yaxley ¨C beside Dolohov
# ['NN', 'JJ', 'NNS', 'DT', 'IN', 'DT', 'DT', 'IN', 'NN', 'JJ', 'IN', 'DT', 'RB', 'IN', 'DT', 'DT', 'VBD', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'MD', 'VB', 'PRP', 'IN', 'DT', 'NN', 'IN', 'DT', 'DT']
#  The two men took their allotted places
# ['DT', 'RB', 'VBD', 'DT', 'DT', 'IN', 'POS', 'DT', 'DT', 'DT', 'DT', 'NNS', 'CC', 'CD', 'POS', 'NN', 'IN', 'VBD', 'IN', 'IN', 'NN', 'DT', '.']
#  Most of the eyes around the table followed Snape, and it was to him that Voldemort spoke first
# ['.']
#  So
# ['RB', '.']
#  My Lord, the Order of the Phoenix intends to move HarryPotter from his current place of safety on Saturday next, at nightfall
# ['DT', 'NN', 'DT', 'VBZ', 'JJ', 'JJ', 'IN', 'DT', 'NN', 'PRP', 'NN', 'DT', 'DT']
#  The interest around the table sharpened palpably: Some stiffened, others fidgeted, all gazing at Snape and Voldemort
# ['PRP$', '.']
#  Saturday
# ['DT', 'DT', 'DT', 'DT', 'TO', 'VB', 'RB', 'DT', 'IN', 'DT', 'DT', 'CC', 'DT', 'DT']
#  at nightfall,  repeated Voldemort
# ['DT', 'DT', 'VBD', 'TO', '.']
#  His red eyes fastened upon Snape's black ones with such intensity that some of the watchers looked away, apparently fearful that they themselves would be scorched by the ferocity of the gaze
# ['PRP$', 'CC', 'NN', 'DT', 'DT', '.']
#  Snape, however, looked calmly back into Voldemort's face and, after a moment or two, Voldemort's lipless mouth curved into something like a smile
# ['DT', 'DT', 'CC', 'CC', 'NN', 'RB', 'DT', 'RB', 'PRP', 'PRP', 'IN', 'DT', 'DT', 'DT', 'VB', 'NN', 'DT', 'NN', 'NN', 'RB', 'VB', 'VB', 'NN', 'DT', 'NN', 'DT', 'NN', 'IN', 'DT', 'NN', 'VBZ', '.']
#  Good
# ['DT', 'DT', 'IN']
#  Very good
# ['PRP$', 'NN', 'TO', 'PRP', 'DT', 'DT', 'DT', 'DT', 'TO', 'DT', 'DT', 'DT', 'DT', 'NN', 'MD', 'VB', '.']
#  And this information comes ¨C    ¨C from the source we discussed,  said Snape
# ['DT', 'NN', 'DT', 'IN', 'DT', 'DT', 'VB', 'DT', 'IN', 'DT']
#  My Lord
# ['NN', 'MD', 'RB', 'VB', 'DT', 'NN', ':', 'PRP', 'NN', 'DT', 'TO', 'VB', '.']
#  Yaxley had leaned forward to look down the long table at Voldemort and Snape
# ['NN', 'DT', 'PRP', 'PRP$', 'CC', 'DT', 'VBD', 'RB', 'DT', 'DT', 'DT']
#  All faces turned to him
# ['NN', 'PRP', 'DT', 'VB', 'IN', 'DT', 'PRP', 'NN', 'DT', 'DT', 'DT']
#  My Lord, I have heard differently
# ['NN', 'DT', 'PRP', 'DT', 'DT', 'DT', 'IN', 'NN', 'DT', 'DT', 'DT', 'DT', 'IN', 'DT', 'IN', 'IN', 'DT', '.']
#  Yaxley waited, but Voldemort did not speak, so he went on,  Dawlish, the Auror, let slip that Potter will not be moved until the thirtieth, the night before the boy turns seventeen
# ['DT', 'CC', 'NN', 'DT', 'PRP', 'DT', 'DT', 'DT', 'IN']
#  Snape was smiling
# ['DT', 'POS', 'VBD', 'IN', 'IN', 'NN', 'DT', '.']
#  My source told me that there are plans to lay a false trail; this must be it
# ['DT', 'DT', 'DT', 'DT', 'IN', 'DT', 'CC', 'DT', 'IN', 'DT', 'PRP', 'DT', 'DT', 'PRP', 'NN', 'DT', 'DT', 'VBN', 'PRP', 'DT', 'DT', 'DT', 'DT', 'DT', 'NN', 'RB', 'DT']
#  No doubt a Confundus Charm has been placed upon Dawlish
# ['NN', 'DT', 'DT', 'DT', 'DT', 'TO', 'DT', 'NN', 'IN', 'RB', 'DT', 'DT', 'PRP', 'VBD', 'TO', 'VB', 'VBN', 'IN', '.']
#  It would not be the first time; he is known to be susceptible
# ['PRP$', 'CC', 'DT', 'PRP', 'IN', 'DT', 'NN', 'DT', 'NN', 'DT', 'IN', 'DT', 'NN', 'VB', 'VBN', 'TO', 'DT', 'DT', 'NN', 'JJ', 'CC', 'PRP', 'IN', 'DT', 'DT', 'NN', 'DT', 'DT', 'DT', 'NN', 'DT', 'IN', 'DT', 'JJ', 'DT', 'CC', 'VBD', 'DT', 'TO', 'DT']
#  I assure you, my Lord, Dawlish seemed quite certain,  said Yaxley
# ['PRP', 'DT', 'DT', 'IN', 'TO', 'NN', 'DT', 'NN', '.']
#  If he has been Confunded, naturally he is certain,  said Snape
# ['DT', 'DT', 'PRP', 'IN', 'IN', 'IN', 'DT', 'CC', 'DT', 'DT']
#  I assure you, Yaxley, the Auror Office will play no further part in the protection of HarryPotter
# ['DT', 'DT', 'DT', 'TO', 'DT', 'NN', 'DT', 'VB', 'NN', 'DT', 'IN', 'DT', 'DT', 'CC', 'DT', 'IN', 'DT', 'MD', '.']
#  The Order believes that we have infiltrated the Ministry
# ['NN', 'IN', 'DT', 'DT', 'NN', 'NN', 'DT', 'IN', 'DT', 'NN', 'IN', 'PRP', 'NN', 'DT', 'PRP$', 'CC', 'IN', 'IN', 'NN', 'DT', 'IN', 'DT', 'DT', 'IN', 'JJ', 'DT', 'NN', 'NN', 'NN', 'PRP', 'DT', 'NN', 'TO', 'NN', 'DT', 'JJ', 'DT', 'IN', 'DT', 'NNS', 'TO', 'DT', 'RB', 'DT', '.']
#  The Order's got one thing right, then, eh
# ['RB', 'DT']
#  said a squat man sitting a short distance from Yaxley; he gave a wheezy giggle that was echoed here and there along the table
# ['CC', 'DT', 'RB', 'DT', 'DT', 'DT', 'NN', 'IN', 'DT', 'IN', 'NN', 'JJ', '.']
#  Voldemort did not laugh
# ['NN', 'DT', 'IN', 'DT', 'DT', 'IN', 'JJ', 'DT']
#  His gaze had wandered upward to the body revolving slowly overhead, and he seemed to be lost in thought
# ['IN', 'DT', 'DT', 'DT', '.']
#  My Lord,  Yaxley went on,  Dawlish believes an entire party of Aurors will be used to transfer the boy ¨C  Voldemort held up a large white hand, and Yaxley subsided at once, watching resentfully as Voldemort turned back to Snape
# ['DT', 'DT', 'NN', '.']
#  Where are they going to hide the boy next
# ['PRP$', 'CC', 'NN', 'DT', 'JJ', 'NN', 'IN', 'DT', '.']
#  At the home of one of the Order,  said Snape
# ['NN', 'DT', 'JJ', 'NN', 'NN', 'DT', 'DT', 'DT', 'IN', 'JJ', 'VBD', 'IN', 'DT', 'DT', 'NN', 'NN', 'IN', 'NN', '.']
#  The place, according to the source, has been given every protection that the Order and Ministry together could provide
# ['DT', 'IN', 'DT', 'IN', 'DT', 'DT', 'VBD', ':', 'NN', 'NN', 'NN', 'DT', 'DT', 'NN', 'DT', 'IN', 'NN', 'DT', 'DT', 'NN', 'IN', 'DT', 'DT']
#  I think that there is little chance of taking him once he is there, my Lord, unless, of course, the Ministry has fallen before next Saturday, which might give us the opportunity to discover and undo enough of the enchantments to break through the rest
# ['NN', 'NN', 'DT', 'DT', 'DT', '.']
#  Well, Yaxley
# ['CC', 'NN', 'NN', 'IN', 'IN', 'DT']
#  Voldemort called down the table, the firelight glinting strangely in his red eyes
# ['NN', 'MD', 'VB', 'VBN', 'IN', 'PRP$', 'NNS', 'IN', 'NN', 'DT']
#  Will the Ministry have fallen by next Saturday
# ['IN', 'DT', 'DT', 'IN', 'DT', 'IN', 'NN', 'NN', 'VB', 'PRP', 'DT', 'DT', 'IN', 'DT']
#  Once again, all heads turned
# ['UH', 'JJ', 'PRP$', 'CC', 'DT', 'NN', 'JJ', 'JJ', 'CC', 'PRP', 'DT', 'DT', 'DT', 'IN', 'DT', 'NNS', 'IN', 'DT', 'DT', 'NNS', 'NN', 'DT', 'DT', 'DT', 'RB', 'IN', 'NN', 'DT', 'IN', 'NN', 'CC', 'DT', 'NN', 'DT', 'DT', 'IN', 'DT', 'DT', 'DT', 'IN', 'NNS']
#  Yaxley squared his shoulders
# ['NN', 'NN', 'NN', 'IN', 'VB', 'DT', 'DT', 'DT', 'PRP', 'DT', 'JJ', 'DT', 'DT', 'IN', 'IN', 'PRP$', 'IN', 'TO', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'CC', 'DT', 'TO', 'IN', 'NN', '.']
#  My Lord, I have good news on that score
# ['DT', 'IN', 'DT', 'PRP$', 'NN', 'NN', 'NN', 'RB', 'NN', 'IN', 'PRP', 'DT', 'IN', 'DT', 'NN', 'DT', '.']
#  I have ¨C with difficulty, and after great effort ¨C succeeded in placing an Imperius Curse upon Pius Thicknesse
# ['DT', 'DT', 'DT', 'NN', 'DT', 'NN', 'DT', 'DT', 'IN', 'NN', 'VB', 'IN', 'IN', 'JJ', 'DT']
#  Many of those sitting around Yaxley looked impressed; his neighbor, Dolohov, a man with a long, twisted face, clapped him on the back
# ['NN', 'PRP', 'DT', 'TO', 'DT', 'NN', 'DT', 'NN', 'DT', 'DT', 'NN', 'MD', 'VB', 'IN', 'NN', 'PRP', 'DT']
#  It is a start,  said Voldemort
# ['PRP', 'DT', 'DT', 'DT', 'DT', 'DT', 'PRP$', 'CC', 'DT', 'DT', 'WP', 'VBD', 'IN', 'TO', 'NN', 'RB', 'IN', 'IN', 'DT']
#  But Thicknesse is only one man
# ['PRP', 'DT', 'DT', 'DT', 'NNS', 'DT', 'IN', 'DT', 'NNS', 'IN', 'DT', 'DT']
#  Scrimgeour must be surrounded by our people before I act
# ['NN', 'NN', 'DT', 'CC', 'PRP', 'DT', 'NN', 'CD', 'PRP', 'DT', 'DT', 'DT']
#  One failed attempt on the Minister's life will set me back a long way
# ['PRP', 'NN', 'RB', 'VB', 'DT', 'DT', 'DT']
#  Yes ¨C my Lord, that is true ¨C but you know, as Head of the Department of Magical Law Enforcement, Thicknesse has regular contact not only with the Minister himself, but also with the Heads of all the other Ministry departments
# ['DT', 'CC', 'NN', 'IN', 'DT', 'IN', 'IN', 'DT', 'DT', 'NN', 'IN', 'CC', 'DT', 'IN', 'DT', 'IN', 'DT', 'NN', 'IN', 'TO', 'VB', 'NN', 'DT', 'DT']
#  It will, I think, be easy now that we have such a high-ranking official under our control, to subjugate the others, and then they can all work together to bring Scrimgeour down
# ['DT', 'DT', 'VB', 'DT', '.']
#  As long as our friend Thicknesse is not discovered before he has converted the rest,  said Voldemort
# ['PRP', 'NN', 'DT', 'TO', 'VB', 'IN', 'DT', '.']
#  At any rate, it remains unlikely that the Ministry will be mine before next Saturday
# ['DT', 'TO', 'DT', 'IN', 'DT']
#  If we cannot touch the boy at his destination, then it must be done while he travels
# ['DT', 'CC', 'VBD', 'IN', 'DT', 'DT', 'RB', 'IN', 'NN', 'DT', 'PRP', 'PRP', 'IN', 'NN', 'DT', 'DT', 'TO', 'DT', 'NN', 'IN', '.']
#  We are at an advantage there, my Lord,  said Yaxley, who seemed determined to receive some portion of approval
# ['DT', 'DT', 'VB', 'TO', 'DT', 'DT', 'PRP', 'DT', 'NN', 'NN', '.']
#  We now have several people planted within the Department of Magical Transport
# ['RB', 'IN', 'DT', 'DT', 'VB', 'PRP$', '.']
#  If Potter Apparates or uses the Floo Network, we shall know immediately
# ['DT', 'NN', 'NN', 'NN', 'RB', 'JJR', 'TO', 'PRP$', 'CC', 'DT', 'TO', 'NN', '.']
#  He will not do either,  said Snape
# ['DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'CC', 'DT', 'DT', 'IN', 'DT', 'IN', 'NN', 'CC', 'PRP', 'IN', 'DT', 'DT', 'DT', 'NN', 'VB', 'DT', 'IN', 'DT', 'POS', 'IN', '.']
#  The Order is eschewing any form of transport that is controlled or regulated by the Ministry; they mistrust everything to do with the place
# ['CC', 'RB', 'VBD', 'TO', 'VB', 'DT', 'JJR', 'TO', 'NN', 'DT', 'TO', 'DT', 'IN', 'DT', 'RB', 'DT', 'DT', 'IN', 'NN', 'DT', '.']
#  All the better,  said Voldemort
# ['NN', 'DT', 'VB', 'DT', 'DT', 'RB', 'DT', 'VB', 'DT', 'IN', 'NN', 'DT', 'DT', 'DT', 'NNS', 'IN', 'DT', 'CC', 'DT', 'DT', 'DT']
#  He will have to move in the open
# ['CC', 'NN', 'DT', 'VB', '.']
#  Easier to take, by far
# ['NN', 'DT', 'DT', 'IN', 'DT', 'NN', 'NN', 'RB', 'DT', '.']
#  Again, Voldemort looked up at the slowly revolving body as he went on,  I shall attend to the boy in person
# ['NN', 'MD', 'VB', 'DT', 'IN', 'TO', 'NN', 'DT', 'NN', 'DT', 'NN', 'DT', '.']
#  There have been too many mistakes where HarryPotter is concerned
# ['DT', 'DT', 'CC', 'IN', 'IN', 'IN', 'TO', 'DT', 'DT', 'JJ', 'DT', 'VBP', 'DT', 'NN', 'IN', 'NN', 'IN', 'NN', 'DT', 'DT']
#  Some of them have been my own
# ['DT', 'IN', 'DT', 'DT', 'DT', 'DT', 'VBD', 'DT', 'DT', 'IN', 'DT', 'VBP', 'DT', 'VBD', 'TO', 'NN', 'IN', 'VB', 'DT', '.']
#  That Potter lives is due more to my errors than to his triumphs
# ['DT', 'DT', 'CC', 'NN', 'DT', 'DT', 'IN', 'NN', 'NN', 'VBN', 'IN', 'DT', 'IN', 'IN', 'NN', 'NNS', 'IN', 'DT', 'IN', 'NN', 'DT', 'DT', 'NN', 'RB', 'VBD', 'TO', 'PRP', 'IN', 'IN', 'PRP$', 'IN', '.']
#  The company around the table watched Voldemort apprehensively, each of them, by his or her expression, afraid that they might be blamed for HarryPotter's continued existence
# ['UH', 'PRP$', 'CC', 'DT', 'DT', 'DT', 'DT', 'DT', 'RB', 'DT', 'DT', 'WP', 'DT', 'VB', 'IN', 'RB', 'JJ', 'IN', 'NN', 'DT', 'DT', 'NN', 'VBD', 'DT', 'NN', 'DT', 'TO', 'VB', '.']
#  Voldemort, however, seemed to be speaking more to himself than to any of them, still addressing the unconscious body above him
# ['DT', 'PRP', 'DT', 'IN', 'NN', 'DT', 'DT', 'NN', 'IN', 'DT', 'NN', 'DT', 'IN', 'IN', 'NN', 'CC', 'DT', 'NN', 'DT', 'IN', '.']
#  I have been careless, and so have been thwarted by luck and chance, those wreckers of all but the best-laid plans
# ['DT', 'NN', 'DT', 'DT', 'IN', 'CC', 'IN', 'DT', 'DT', 'DT', 'JJ', 'DT', 'IN', 'NN', 'PRP', 'NN', 'DT', 'VB', '.']
#  But I know better now
# ['NN', 'DT', 'VB', 'IN', 'DT', 'TO', 'CC', 'DT', 'DT', 'IN', 'IN', 'IN', 'PRP', 'IN', 'NN', 'VBP', 'TO', 'NN', '.']
#  I understand those things that I did not understand before
# ['DT', 'DT', 'DT', 'NN', 'DT', 'IN', 'CC', ':', 'PRP', 'NN', 'DT', 'DT', 'DT', 'PRP', 'DT', 'TO', 'CC', 'IN', 'IN', 'DT', 'DT']
#  I must be the one to kill HarryPotter, and I shall be
# ['DT', '.']
#  At these words, seemingly in response to them, a sudden wail sounded, a terrible, drawn-out cry of misery and pain
# ['DT', '.']
#  Many of those at the table looked downward, startled, for the sound had seemed to issue from below their feet
# ['POS', 'VB', '.', 'NN', 'NN', 'VB', 'DT', 'DT', 'IN', 'PRP', 'TO', 'DT', 'DT', 'DT', 'DT']
#  Wormtail,  said Voldemort, with no change in his quiet, thoughtful tone, and without removing his eyes from the revolving body above,  have I not spoken to you about keeping our prisoner quiet
# ['NN', 'DT', 'VBD', '.']
#  Yes, m-my Lord,  gasped a small man halfway down the table, who had been sitting so low in his chair that it appeared, at first glance, to be unoccupied
# ['NN', 'IN', 'VBD', 'NN', 'DT', 'DT', 'IN', 'DT', 'NN', 'DT', 'NN', 'NNS', 'VBD', 'VBN', 'DT', 'DT']
#  Now he scrambled from his seat and scurried from the room, leaving nothing behind him but a curious gleam of silver
# ['PRP', 'PRP', 'VBD', 'NN', 'NN', 'DT', 'DT']
#  As I was saying,  continued Voldemort, looking again at the tense faces of his followers,  I understand better now
# ['PRP$', '.']
#  I shall need, for instance, to borrow a wand from one of you before I go to kill Potter
# ['PRP', 'DT', '.']
#  The faces around him displayed nothing but shock; he might have announced that he wanted to borrow one of their arms
# ['NN', 'NN', 'PRP', 'DT']
#  No volunteers
# ['NN', '.', 'DT', 'DT', 'DT', 'DT', 'NN', '.']
#  said Voldemort
# ['PRP', 'DT', 'DT', 'DT', 'DT', 'RB', 'DT', 'DT', 'DT', 'PRP', 'DT', 'PRP', 'IN', 'IN', 'DT', 'DT', 'RB', 'PRP', 'DT', 'CC', 'DT', 'DT', 'DT', 'PRP', 'NN', 'IN', 'VBD', 'NN', 'IN', 'NN', '.']
#  Let's see
# ['DT', 'PRP', 'TO', 'DT', 'VBD', 'NN', 'DT', 'IN', 'NN', 'VB', 'NN', 'DT', 'DT', 'DT', 'DT', 'NN', 'DT', 'TO', 'CC', 'WP', 'PRP', 'NN', 'IN', 'IN', 'IN', 'IN', 'NN', 'JJ', 'NNS', 'DT', 'NN', '.']
#  Lucius, I see no reason for you to have a wand anymore
# ['DT', 'NN', '.']
#  Lucius Malfoy looked up
# ['NN', 'PRP$', 'CC', 'NN', 'DT']
#  His skin appeared yellowish and waxy in the firelight, and his eyes were sunken and shadowed
# ['DT', 'DT', '.']
#  When he spoke, his voice was hoarse
# ['DT', 'JJ', 'DT', 'DT']
#  My Lord
# ['JJ', 'DT', '.']
#  Your wand, Lucius
# ['PRP', 'VBD', 'IN', 'NN', 'DT', 'DT', 'DT', 'DT', '.']
#  I require your wand
# ['NN', 'DT', 'DT', 'DT', 'DT', 'NNS', 'IN', 'DT', 'DT', 'IN', 'DT', 'JJ', 'NN', 'VBD', 'PRP', 'VBN', 'TO', 'NN', 'POS', 'DT', 'IN', 'DT', 'IN', 'NN', '.']
#  I
# ['DT', 'NN', 'DT', 'RB', 'NN', 'IN', 'CC', 'WP$', 'NNS', 'NN', 'DT']
#  Malfoy glanced sideways at his wife
# ['NN', 'PRP', 'PRP$', 'DT', '.']
#  She was staring straight ahead, quite as pale as he was, her long blonde hair hanging down her back, but beneath the table her slim fingers closed briefly on his wrist
# ['PRP$', 'DT']
#  At her touch, Malfoy put his hand into his robes, withdrew a wand, and passed it along to Voldemort, who held it up in front of his red eyes, examining it closely
# ['RB', 'IN', 'DT', 'IN', '.']
#  What is it
# ['NN', 'DT', 'NN', 'PRP', 'PRP', 'NN', 'NN', 'NN', 'DT', 'RB', 'DT', 'IN', '.']
#  Elm, my Lord,  whispered Malfoy
# ['CC', 'NN', 'DT', 'NN', 'DT', 'PRP', 'DT', 'PRP', 'DT', 'VB', 'JJR', 'DT', 'DT', 'IN', 'DT', '.', 'DT', 'NN', 'NN', 'IN', 'PRP$', 'NN', 'IN', 'PRP', 'PRP', 'DT', 'DT', 'PRP', '.']
#  And the core
# ['IN', 'JJ', 'IN', 'PRP$', 'CC']
#  Dragon ¨C dragon heartstring
# ['JJ', 'NN', 'NN', '.']
#  Good,  said Voldemort
# ['DT', 'IN', 'NN', 'VBD', 'TO', 'NN', 'IN', 'RB', 'DT', 'DT', 'NN', 'IN', 'DT', 'TO', 'IN']
#  He drew out his wand and compared the lengths
# ['IN', 'CC', 'CD', 'IN', 'DT', 'DT', 'DT', 'VBD', 'DT', 'NN', 'DT', 'DT', 'IN', 'VBD', ':', 'IN', 'DT', 'MD', 'VB', 'DT', 'IN', 'DT', 'DT', 'NN', 'DT', 'DT', 'DT', 'JJ', 'DT', 'PRP', 'TO', 'NN', 'RB', 'IN', 'POS', 'DT']
#  Lucius Malfoy made an involuntary movement; for a fraction of a second, it seemed he expected to receive Voldemort's wand in exchange for his own
# ['NN', 'VBD', 'IN', 'NN', 'DT', 'DT', 'TO', 'NN', 'DT', 'POS', ':', 'NN', 'NN', 'DT', 'NN', 'IN', 'DT', 'DT', ':', 'NN', 'NNS', 'NN', 'DT', 'DT', 'NN', 'IN', 'NN', 'IN']
#  The gesture was not missed by Voldemort, whose eyes widened maliciously
# ['CC', 'VBD', 'DT', 'DT', 'DT', 'NN', 'IN', 'IN', 'IN', 'RB', 'IN', 'DT', 'NN', 'DT']
#  Give you my wand, Lucius
# ['WRB', 'VB', 'DT', 'DT', 'VB', 'RB', 'DT', 'NN', 'DT', '.']
#  My wand
# ['NN', 'PRP$', 'NN', 'PRP$', 'NN', 'TO', 'PRP', 'RB', 'DT', 'RB', 'IN', 'DT', 'IN', 'TO', 'NN', 'IN', 'RB', 'DT', 'DT']
#  Some of the throng sniggered
# ['IN', 'NN', 'PRP$', 'CC', 'DT', 'NN', 'DT']
#  I have given you your liberty, Lucius, is that not enough for you
# ['NN', 'DT', 'NN', 'DT', 'PRP', 'NN', 'DT', 'IN', 'NN', 'IN', '.']
#  But I have noticed that you and your family seem less than happy of late
# ['PRP', 'NN', 'NN', 'NN', 'JJ', 'PRP', '.']
#  What is it about my presence in your home that displaces you, Lucius
# ['TO', 'DT', 'VBN', 'NN', 'NN', 'DT', 'DT', 'JJ', 'NN', 'DT', 'PRP', 'NNS', 'DT', 'IN', 'CC', 'DT', 'DT', 'DT']
#  Nothing ¨C nothing, my Lord!  Such lies Lucius
# ['TO', 'NN', 'NN', 'NN', 'IN', 'DT', 'WP', 'DT', 'VB', 'DT', 'IN', 'DT', 'DT', 'IN', 'NN', 'DT', 'DT', 'NN', 'DT', 'CC', 'DT', 'DT', 'DT', 'NN', 'TO', 'DT', 'NN', 'DT']
#  The soft voice seemed to hiss on even after the cruel mouth had stopped moving
# ['PRP$', 'CC', 'DT', 'DT', 'DT', 'DT', 'DT', 'RB', 'DT', 'DT', 'PRP', 'NN', 'IN', 'NN', 'IN', 'NN', 'NN', 'DT', 'IN', 'TO', 'DT', 'PRP', 'PRP', 'IN', 'PRP$', 'DT', '.']
#  One or two of the wizards barely repressed a shudder as the hissing grew louder; something heavy could be heard sliding across the floor beneath the table
# ['DT', 'DT', 'VB', 'DT', 'JJ', 'DT']
#  The huge snake emerged to climb slowly up Voldemort's chair
# ['PRP', 'DT', 'NN', 'PRP', 'NN', 'DT', 'NN', 'PRP', 'IN', 'VB', 'NN', 'PRP', 'DT', 'DT', 'DT', 'DT', 'NN', 'NNS', 'DT', 'PRP', 'DT', 'IN', 'DT', 'DT', 'DT', 'PRP', 'DT', 'DT', 'NN', 'DT', 'DT', 'DT', 'DT', 'DT', 'CC', 'IN', 'PRP', 'CC', 'MD', 'RB', 'DT', 'PRP', 'IN', 'IN', '.']
#  It rose, seemingly endlessly, and came to rest across Voldemort's shoulders: its neck the thickness of a man's thigh; its eyes, with their vertical slits for pupils, unblinking
# ['DT', 'JJ', 'DT', 'DT', 'CC', 'NN', 'DT', 'NN', 'DT', 'NN', 'TO', 'IN', 'NN', 'DT', 'PRP', 'IN', 'DT']
#  Voldemort stroked the creature absently with long thin fingers, still looking at Lucius Malfoy
# ['DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'IN', '.']
#  Why do the Malfoys look so unhappy with their lot
# ['PRP', 'DT', 'NN', 'NN', ':', 'PRP', 'NNS', 'VBD', 'NN', 'DT', 'IN', '.']
#  Is my return, my rise to power, not the very thing they professed to desire for so many years
# ['PRP$', 'CC', 'DT', 'NN', 'DT', 'IN', 'CC', 'DT', '.']
#  Of course, my Lord,  said Lucius Malfoy
# ['DT', 'JJ', 'DT', '.', 'RB', 'DT', 'NN', 'DT', 'DT', 'RB', 'DT', 'NN', 'DT', 'DT', 'DT', 'DT', 'IN', 'PRP', 'DT', 'NN', '.']
#  His hand shook as he wiped sweat from his upper lip
# ['PRP', 'DT', 'DT', 'NN', 'PRP', 'NN', 'DT', 'NN', '.']
#  We did desire it ¨C we do
# ['NN', 'IN', 'DT', 'DT', 'PRP', 'DT', 'PRP$', '.']
#  To Malfoy's left, his wife made an odd, stiff nod, her eyes averted from Voldemort and the snake
# ['NN', 'DT', 'IN', 'PRP', 'NN', 'DT']
#  To his right, his son, Draco, who had been gazing up at the inert body overhead, glanced quickly at Voldemort and away again, terrified to make eye contact
# ['DT', 'PRP', 'NN', 'DT', 'DT']
#  My Lord,  said a dark woman halfway down the table, her voice constricted with emotion,  it is an honor to have you here, in our family's house
# ['PRP', 'DT', 'PRP', 'DT', 'DT', 'VBD', 'PRP', 'IN']
#  There can be no higher pleasure
# ['PRP', 'MD', 'VB', 'RB', '.']
#  She sat beside her sister, as unlike her in looks, with her dark hair and heavily lidded eyes, as she was in bearing and demeanor; where Narcissa sat rigid and impassive, Bellatrix leaned toward Voldemort, for mere words could not demonstrate her longing for closeness
# ['DT', 'DT', 'DT', 'IN', 'IN', 'IN', 'DT', 'IN', 'DT', 'DT', 'DT']
#  No higher pleasure,  repeated Voldemort, his head tilted a little to one side as he considered Bellatrix
# ['DT', 'DT', 'DT', 'TO', 'DT', 'JJ', ':', 'DT', 'JJ', 'VBD', 'DT', 'DT', 'NN', 'DT', '.']
#  That means a great deal, Bellatrix, from you
# ['DT', 'DT', 'DT', 'IN', 'DT', 'DT', 'VBN', 'NN', 'IN', 'NN', 'DT', 'NN', 'DT', 'CC', 'DT', 'DT', 'DT', 'NN', 'RB', 'DT', 'NN', 'RB', 'DT', 'VBD', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT']
#  Her face flooded with color; her eyes welled with tears of delight
# ['DT', 'DT', 'RB', 'RB', 'PRP', 'NN', 'DT', 'DT', 'VBD', 'DT', 'RB', 'NN', '.']
#  My Lord knows I speak nothing but the truth!  No higher pleasure
# ['PRP', 'NN', 'DT', 'NN', 'IN', 'PRP$', 'PRP$', 'CC', 'PRP', 'NN', 'IN', 'DT', 'IN', 'IN', '.']
#  even compared with the happy event that, I hear, has taken place in your family this week
# ['PRP', 'JJ', 'DT', 'DT', 'NN', 'JJ', 'DT', 'RB', 'VB', 'NNS', 'IN', 'PRP$', 'NN', 'IN', 'PRP', 'DT', 'DT', '.']
#  She stared at him, her lips parted, evidently confused
# ['NN', 'DT', 'DT', 'IN', 'TO', 'VB', 'NN', 'DT', 'IN', 'PRP', 'CC', 'DT', 'DT', 'PRP', 'DT']
#  I don't know what you mean, my Lord
# ['DT', 'DT', 'PRP', 'DT']
#  I'm talking about your niece, Bellatrix
# ['DT', 'CC', 'DT', 'IN', 'NN', 'NN', 'DT', 'NN', 'NN', 'DT', 'DT', 'RB', 'DT', 'DT', 'DT', '.']
#  And yours, Lucius and Narcissa
# ['NN', 'PRP', 'DT', 'DT', '.']
#  She has just married the werewolf, Remus Lupin
# ['DT', 'DT', ':', 'DT', 'DT', 'VBD', 'IN', 'CC', 'DT', 'NN', 'DT', 'WP', 'DT', 'DT', 'RB', 'IN', 'NN', 'JJ', 'DT', 'DT', 'DT', 'NN', 'DT', '.']
#  You must be so proud
# ['PRP', 'NN', 'PRP', 'DT', 'DT', 'NN', 'DT', 'PRP', 'PRP', 'JJ', 'DT', 'DT', 'DT', 'DT', 'NN', 'DT']
#  There was an eruption of jeering laughter from around the table
# ['DT', 'DT', 'CC', 'IN', 'DT', 'DT', 'DT']
#  Many leaned forward to exchange gleeful looks; a few thumped the table with their fists
# ['.']
#  The giant snake, disliking the disturbance, opened its mouth wide and hissed angrily, but the Death Eaters did not hear it, so jubilant were they at Bellatrix and the Malfoys' humiliation
# ['DT', 'DT', 'DT', 'NN', 'DT', '.']
#  Bellatrix's face, so recently flushed with happiness, had turned an ugly, blotchy red
# ['DT', 'IN', 'PRP$', 'JJS', 'DT', 'NNS', 'VB', 'DT', 'NN', 'DT', 'IN', 'NN', 'PRP', 'DT', 'DT', 'DT', 'DT', 'DT', 'NN', 'DT', 'DT', 'IN', 'PRP', 'MD', 'VB', 'PRP', 'MD', 'PRP', 'RB', 'TO', 'VB', 'NN', 'DT']
#  She is no niece of ours, my Lord,  she cried over the outpouring of mirth
# ['VB', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'IN', 'DT', '.']
#  We ¨C Narcissa and I ¨C have never set eyes on our sister since she married the Mudblood
# ['UH', 'PRP$', 'CC', 'NN', 'DT', 'DT', 'PRP', 'NNS', 'DT', 'NN', 'DT', 'IN', 'DT', 'DT']
#  This brat has nothing to do with either of us, nor any beast she marries
# ['DT', 'DT', 'NN', 'DT']
#  What say you, Draco
# ['PRP', 'DT', 'DT', 'NN', 'DT', '.']
#  asked Voldemort, and though his voice was quiet, it carried clearly through the catcalls and jeers
# ['DT', 'IN', 'PRP', 'DT', 'RB', 'IN', 'DT', 'CC', '.', 'PRP', 'DT', 'VB', 'DT', 'DT', 'DT', 'DT', 'IN', 'PRP', 'NN', 'IN', 'DT', 'IN', 'DT', 'JJ', 'NN', 'DT', '.', 'CC', 'DT', 'NN', 'DT', 'DT', 'IN', 'NN', 'NN', 'DT', 'DT', 'RB', 'IN', 'NN', 'NN', 'IN', 'DT', 'DT', 'DT', 'DT', 'NN', 'DT', 'IN', '.']
#  Will you babysit the cubs
# ['DT', 'NN', 'DT', 'TO', 'NN', 'NN', 'DT', 'DT', 'DT', 'DT', 'TO', 'VB', 'DT', 'IN', '.']
#  The hilarity mounted; Draco Malfoy looked in terror at his father, who was staring down into his own lap, then caught his mother's eye
# ['VB', 'PRP', 'NN', 'PRP$', 'JJS', '.']
#  She shook her head almost imperceptibly, then resumed her own deadpan stare at the opposite wall
# ['DT', 'DT', 'DT', 'NN', 'NNS', 'TO', 'DT', 'NN', 'RB', 'DT']
#  Enough,  said Voldemort, stroking the angry snake
# ['DT', 'IN', 'DT', 'DT', 'DT', 'VBD', 'IN', 'IN', 'DT', 'DT', 'DT', 'DT', 'DT', 'IN', 'DT', 'DT', 'VB', 'NN', 'IN', 'TO', 'VB', '.']
#  Enough
# ['DT', 'PRP', 'VBD', 'TO', 'DT', 'DT', 'NN', 'DT', 'DT', 'DT', 'IN', 'DT', 'DT', 'DT', 'NN', 'NN', 'NN']
#  And the laughter died at once
# ['PRP', 'PRP']
#  Many of our oldest family trees become a little diseased over time,  he said as Bellatrix gazed at him, breathless and imploring,  You must prune yours, must you not, to keep it healthy
# ['DT', 'UH', 'DT', 'DT', 'DT', 'DT', 'IN', 'VBD', 'RB', 'DT', 'DT']
#  Cut away those parts that threaten the health of the rest
# ['DT', 'PRP', 'DT']
#  Yes, my Lord,  whispered Bellatrix, and her eyes swam with tears of gratitude again
# ['DT', 'CC', 'IN', 'DT', 'DT', 'IN', 'NN', 'NN', 'DT', 'DT']
#  At the first chance!  You shall have it,  said Voldemort
# ['DT', 'NN', 'NN', 'DT', '.']
#  And in your family, so in the world
# ['DT', 'DT', 'DT', 'DT', 'DT', 'VBN', 'PRP', 'VBD', 'DT', 'TO', 'VB', 'DT', 'PRP', 'DT']
#  we shall cut away the cancer that infects us until only those of the true blood remain
# ['CC', 'PRP', 'MD', 'RB', 'DT', 'DT', 'PRP', 'DT', 'DT', '.']
#  Voldemort raised Lucius Malfoy's wand, pointed it directly at the slowly revolving figure suspended over the table, and gave it a tiny flick
# ['IN', 'DT', 'IN', 'PRP', 'WP', 'VB', 'RB', 'DT', 'PRP', 'DT', 'IN', 'PRP', 'IN', 'IN', 'DT', 'DT', 'WP', 'NN', 'RB', 'DT', 'DT', 'DT', 'NN', 'IN', 'DT', 'DT', 'DT']
#  The figure came to life with a groan and began to struggle against invisible bonds
# ['DT', 'VBD', 'DT', 'NN', 'IN', 'IN', 'DT', 'DT', 'DT']
#  Do you recognize our guest, Severus
# ['DT', 'DT', 'PRP', 'DT', 'NN', 'IN', 'NNS', 'DT']
#  asked Voldemort
# ['UH', '.']
#  Snape raised his eyes to the upside down face
# ['IN', 'DT', 'DT', 'DT', 'NN', 'IN', 'NN', 'DT', 'DT', 'DT', 'IN', 'NNS', '.', 'WRB', 'DT', 'DT', 'RB', 'RB', 'NN', 'IN', 'PRP', '.', 'IN', 'IN', 'DT', 'DT', 'DT', 'DT', 'IN', 'DT', '.']
#  All of the Death Eaters were looking up at the captive now, as though they had been given permission to show curiosity
# ['DT', 'DT', 'VBD', 'TO', 'DT', 'DT', 'DT']
#  As she revolved to face the firelight, the woman said in a cracked and terrified voice,  Severus! Help me!  Ah, yes,  said Snape as the prisoner turned slowly away again
# ['NN', '.', 'DT', '.', 'DT', '.']
#  And you, Draco
# ['NN', 'DT', 'CC', 'NN', 'DT', 'NN', 'IN', 'DT', 'DT', 'DT', 'DT', 'VBD', 'NN', 'DT', 'NN', 'DT']
#  asked Voldemort, stroking the snake's snout with his wand-free hand
# ['RB', 'IN', 'NN', 'IN', 'DT', 'IN', 'DT', 'IN', 'IN', 'DT', 'NN', 'DT', 'PRP', 'IN', 'DT', 'VBD', 'DT', 'DT', 'NN', 'IN', 'NN', 'IN', 'DT', 'DT', '.']
#  Draco shook his head jerkily
# ['DT', 'PRP', 'DT', 'MD', 'DT', 'DT', 'NN', 'IN', 'DT', 'VBD', 'DT', 'DT']
#  Now that the woman had woken, he seemed unable to look at her anymore
# ['DT', 'IN', 'IN', 'DT', 'NN', 'NN', 'DT', 'IN', 'DT', 'DT', 'JJS', 'DT', 'DT', '.', 'PRP', 'MD', 'DT', 'PRP', 'DT', 'DT', 'NN', 'NNS', '.', 'CC', 'DT', 'NN', 'VBD', '.', 'NN', 'DT', 'NN', '.']
#  But you would not have taken her classes,  said Voldemort
# ['DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'IN', 'IN', 'POS', '.']
#  For those of you who do not know, we are joined here tonight by Charity Burbage who, until recently, taught at Hogwarts School of Witchcraft and Wizardry
# ['IN', 'DT', 'NN', 'NN', 'DT', 'DT', 'VBD', 'TO', 'DT', 'DT']
#  There were small noises of comprehension around the table
# ['DT', 'VBD', 'IN', 'IN', 'PRP', 'NNS', 'IN', 'PRP', 'DT']
#  A broad, hunched woman with pointed teeth cackled
# ['DT', 'VBD', 'DT', 'DT', 'PRP', 'RB', 'DT', 'DT', 'PRP', 'VBD', 'RB', 'DT', 'IN', 'NN', 'DT']
#  Yes
# ['DT', 'DT', 'DT', 'DT', 'IN', 'JJ', 'NN', 'DT', 'DT', 'CC', 'IN', 'DT', '.']
#  Professor Burbage taught the children of witches and wizards all about Muggles
# ['DT', 'VBD', 'NN', 'DT', 'IN', 'DT', 'IN', 'DT', 'DT', 'VB', 'NN', 'VBD', 'DT', 'DT']
#  how they are not so different from us
# ['DT', 'IN', 'DT', 'DT', 'DT', 'DT', 'DT', 'IN', 'DT', 'DT']
#  One of the Death Eaters spat on the floor
# ['DT', 'VBD', 'IN', 'IN', 'NN', 'IN', 'DT', '.']
#  Charity Burbage revolved to face Snape again
# ['IN', 'DT', 'DT', 'CC', 'IN', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'DT', 'IN', 'NN', 'NNS', 'IN', 'DT', 'NN', '.']
#  Severus

# %% [markdown]
# ## Cool stuff

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6eeea9da5481> in <module>()
#       1 import os
#       2 for var in os.environ:
# ----> 3     c.Spawner.env_keep.append(var)
#       4
#       5 from nltk.parse.stanford import StanfordParser
#
# NameError: name 'c' is not defined
